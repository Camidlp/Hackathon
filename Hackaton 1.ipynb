# %% [markdown]
# # Ejercicio de ML 1

# %% [markdown]
# ### 1) Importar librerias

# %%
import pandas as pd
import sklearn as sk
import numpy as np
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# ### 2) Leer y visualizar tabla

# %%
ht = pd.read_csv('C:/Users/kmyde/Desktop/HENRY DATA SCIENCE/Machine Learning/Hackathon/Housing Dreams/house_train_raw.csv')

# %%
ht.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
ht.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
ht.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# ### 3) Limpieza de Tabla train y transformacion de datos

# %%
ht.drop([ 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal', '3SsnPorch', 'ScreenPorch', 'LowQualFinSF', 'BsmtFinSF2','BsmtFinSF1'],axis=1, inplace=True)

# %%
ht.fillna('NaN', inplace=True)

# %%
ht.head(11)
# Out:
#     Id  MSSubClass MSZoning LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL        65.0     8450   Pave   NaN      Reg
# 1    2          20       RL        80.0     9600   Pave   NaN      Reg
# 2    3          60       RL        68.0    11250   Pave   NaN      IR1
# 3    4          70       RL        60.0     9550   Pave   NaN      IR1
# 4    5          60       RL        84.0    14260   Pave   NaN      IR1
# 5    6          50       RL        85.0    14115   Pave   NaN      IR1
# 6    7          20       RL        75.0    10084   Pave   NaN      Reg
# 7    8          60       RL         NaN    10382   Pave   NaN      IR1
# 8    9          50       RM        51.0     6120   Pave   NaN      Reg
# 9   10         190       RL        50.0     7420   Pave   NaN      Reg
# 10  11          20       RL        70.0    11200   Pave   NaN      Reg
#
#    LandContour Utilities  ... GarageCond PavedDrive WoodDeckSF OpenPorchSF  \
# ...

# %% [markdown]
# Mapping

# %%
dic = {'RL': 1, 'RM': 2, 'C (all)': 3, 'FV': 4, 'RH': 5}
ht['MSZoningMap'] = ht.MSZoning.map(dic)
ht.drop(columns='MSZoning', inplace=True)

# %%
dic1 = {'Pave': 1, 'Grvl': 2}
ht['StreetMap'] = ht.Street.map(dic1)
ht.drop(columns='Street', inplace=True)

# %%
dic2 = {'Pave': 1, 'Grvl': 2, 'NaN': 3}
ht['AlleyMap'] = ht.Alley.map(dic2)
ht.drop(columns='Alley', inplace=True)

# %%
dic3 = {'Reg': 1, 'IR1': 2, 'IR2': 3, 'IR3': 4}
ht['LotShapeMap'] = ht.LotShape.map(dic3)
ht.drop(columns='LotShape', inplace=True)

# %%
dic4 = {'Lvl': 1, 'Low': 2, 'HLS': 3, 'Bnk': 4}
ht['LandContourMap'] = ht.LandContour.map(dic4)
ht.drop(columns='LandContour', inplace=True)

# %%
dic5 = {'AllPub': 1, 'NoSeWa': 2}
ht['UtilitiesMap'] = ht.Utilities.map(dic5)
ht.drop(columns='Utilities', inplace=True)

# %%
dic6 = {'Inside': 1, 'Corner': 2, 'CulDSac': 3, 'FR2': 4, 'FR3': 5}
ht['LotConfigMap'] = ht.LotConfig.map(dic6)
ht.drop(columns='LotConfig', inplace=True)

# %%
dic7 = {'Gtl': 1, 'Mod': 2, 'Sev': 3}
ht['LandSlopeMap'] = ht.LandSlope.map(dic7)
ht.drop(columns='LandSlope', inplace=True)

# %%
dic8 = {'Blmngtn': 1, 'Blueste': 2, 'BrDale': 3, 'BrkSide': 4, 'ClearCr':5,	
        'CollgCr': 6, 'Crawfor': 7, 'Edwards': 8, 'Gilbert': 9, 'IDOTRR': 10, 'MeadowV': 11,
        'Mitchel': 12,	'Names': 13, 'NoRidge': 14, 'NPkVill': 15, 'NridgHt':16,
        'NWAmes': 17, 'OldTown': 18, 'SWISU': 19, 'Sawyer': 20, 'SawyerW': 21,
        'Somerst': 22, 'StoneBr': 23, 'Timber': 24, 'Veenker': 25}
ht['NeighborhoodMap'] = ht.Neighborhood.map(dic8)
ht.drop(columns='Neighborhood', inplace=True)

# %%
dic9 = {'Artery': 1, 'Feedr': 2, 'Norm': 3, 'RRNn': 4, 'RRAn': 5, 'PosN': 6, 'PosA': 7,
        'RRNe': 8, 'RRAe': 9}
ht['Condition1Map'] = ht.Condition1.map(dic9)
ht.drop(columns='Condition1', inplace=True)

# %%
dic10 = {'Artery': 1, 'Feedr': 2, 'Norm': 3, 'RRNn': 4, 'RRAn': 5, 'PosN': 6, 'PosA': 7,
        'RRNe': 8, 'RRAe': 9}
ht['Condition2Map'] = ht.Condition2.map(dic10)
ht.drop(columns='Condition2', inplace=True)

# %%
dic11 = {'1Fam': 1, '2Fam': 2, 'Duplx': 3, 'TwnhsE': 4, 'TwnhsI': 5}
ht['BldgTypeMap'] = ht.BldgType.map(dic11)
ht.drop(columns='BldgType', inplace=True)

# %%
dic12 = {'1Story': 1, '1.5Fin': 2, '1.5Unf': 3, '2Story': 4, '2.5Fin': 5, '2.5Unf': 6, 
         'SFoyer': 7, 'SLvl': 8}
ht['HouseStyleMap'] = ht.HouseStyle.map(dic12)
ht.drop(columns='HouseStyle', inplace=True)

# %%
dic13 = {'Flat': 1, 'Gable': 2, 'Gambrel': 3, 'Hip': 4, 'Mansard': 5, 'Shed': 6}
ht['RoofStyleMap'] = ht.RoofStyle.map(dic13)
ht.drop(columns='RoofStyle', inplace=True)

# %%
dic14 = {'CompShg': 1, 'WdShngl': 2, 'Metal': 3, 'WdShake': 4, 'Membran': 5, 'Tar&Grv': 6}
ht['RoofMatlMap'] = ht.RoofMatl.map(dic14)
ht.drop(columns='RoofMatl', inplace=True)

# %%
dic15 = {'AsbShng': 1, 'AsphShn':2, 'BrkComm': 3, 'BrkFace':	4, 'CBlock': 5, 'CemntBd': 6,
         'HdBoard': 7, 'ImStucc': 8, 'MetalSd': 9, 'Other':	10, 'Plywood': 11, 'PreCast': 12,	
         'Stone': 13, 'Stucco':	14, 'VinylSd':15, 'Wd Sdng': 16, 'WdShing':	17}
ht['Exterior1stMap'] = ht.Exterior1st.map(dic15)
ht.drop(columns='Exterior1st', inplace=True)

# %%
dic16 = {'AsbShng': 1, 'AsphShn':2, 'BrkComm': 3, 'BrkFace':	4, 'CBlock': 5, 'CemntBd': 6,
         'HdBoard': 7, 'ImStucc': 8, 'MetalSd': 9, 'Other':	10, 'Plywood': 11, 'PreCast': 12,	
         'Stone': 13, 'Stucco':	14, 'VinylSd':15, 'Wd Sdng': 16, 'WdShing':	17}
ht['Exterior2ndMap'] = ht.Exterior2nd.map(dic16)
ht.drop(columns='Exterior2nd', inplace=True)

# %%
dic17 = {'BrkCmn': 1, 'BrkFace': 2, 'CBlock': 3, 'None': 4, 'Stone': 5}
ht['MasVnrTypeMap'] = ht.MasVnrType.map(dic17)
ht.drop(columns='MasVnrType', inplace=True)

# %%
dic18 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5}
ht['ExterQualMap'] = ht.ExterQual.map(dic18)
ht.drop(columns='ExterQual', inplace=True)

# %%
dic19 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5}
ht['ExterCondMap'] = ht.ExterCond.map(dic19)
ht.drop(columns='ExterCond', inplace=True)

# %%
dic20 = {'BrkTil': 1, 'CBlock': 2, 'PConc': 3, 'Slab': 4, 'Stone': 5, 'Wood': 6}
ht['FoundationMap'] = ht.Foundation.map(dic20)
ht.drop(columns='Foundation', inplace=True)

# %%
dic21 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5, 'NA': 6}
ht['BsmtQualMap'] = ht.BsmtQual.map(dic21)
ht.drop(columns='BsmtQual', inplace=True)

# %%
dic22 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5, 'NA': 6}
ht['BsmtCondMap'] = ht.BsmtCond.map(dic22)
ht.drop(columns='BsmtCond', inplace=True)

# %%
dic23 = {'Gd': 1, 'Av': 2, 'Mn': 3, 'No': 4, 'NA': 5}
ht['BsmtExposureMap'] = ht.BsmtExposure.map(dic23)
ht.drop(columns='BsmtExposure', inplace=True)

# %%
dic24 = {'GLQ': 1, 'ALQ': 2, 'BLQ': 3, 'Rec': 4, 'LwQ': 5, 'Unf': 6, 'NA': 7}
ht['BsmtFinType1Map'] = ht.BsmtFinType1.map(dic24)
ht.drop(columns='BsmtFinType1', inplace=True)

# %%
dic25 = {'GLQ': 1, 'ALQ': 2, 'BLQ': 3, 'Rec': 4, 'LwQ': 5, 'Unf': 6, 'NA': 7}
ht['BsmtFinType2Map'] = ht.BsmtFinType2.map(dic25)
ht.drop(columns='BsmtFinType2', inplace=True)

# %%
dic26 = {'Floor': 1, 'GasA': 2, 'GasW': 3, 'Grav': 4, 'OthW': 5, 'Wall': 6}
ht['HeatingMap'] = ht.Heating.map(dic26)
ht.drop(columns='Heating', inplace=True)

# %%
dic27 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5}
ht['HeatingQCMap'] = ht.HeatingQC.map(dic27)
ht.drop(columns='HeatingQC', inplace=True)

# %%
dic28 = {'N': 1, 'Y': 2}
ht['CentralAirMap'] = ht.CentralAir.map(dic28)
ht.drop(columns='CentralAir', inplace=True)

# %%
dic29 = {'SBrkr': 1, 'FuseA': 2, 'FuseF': 3, 'FuseP': 4, 'Mix': 5}
ht['ElectricalMap'] = ht.Electrical.map(dic29)
ht.drop(columns='Electrical', inplace=True)

# %%
dic30 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5}
ht['KitchenQualMap'] = ht.KitchenQual.map(dic30)
ht.drop(columns='KitchenQual', inplace=True)

# %%
dic31 = {'Typ': 1, 'Min1': 2, 'Min2': 3, 'Mod': 4, 'Maj1': 5, 'Maj2': 6, 'Sev': 7, 'Sal': 8}
ht['FunctionalMap'] = ht.Functional.map(dic31)
ht.drop(columns='Functional', inplace=True)

# %%
dic32 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5, 'NA': 6}
ht['FireplaceQuMap'] = ht.FireplaceQu.map(dic32)
ht.drop(columns='FireplaceQu', inplace=True)

# %%
dic33 = {'2Types': 1, 'Attchd': 2, 'Basment': 3, 'BuiltIn': 4, 'CarPort': 5, 'Detchd': 6, 'NA': 7}
ht['GarageTypeMap'] = ht.GarageType.map(dic33)
ht.drop(columns='GarageType', inplace=True)

# %%
dic34 = {'Fin': 1, 'RFn': 2, 'Unf': 3, 'NA': 4}
ht['GarageFinishMap'] = ht.GarageFinish.map(dic34)
ht.drop(columns='GarageFinish', inplace=True)

# %%
dic35 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5, 'NA': 6}
ht['GarageQualMap'] = ht.GarageQual.map(dic35)
ht.drop(columns='GarageQual', inplace=True)

# %%
dic36 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5, 'NA': 6}
ht['GarageCondMap'] = ht.GarageCond.map(dic36)
ht.drop(columns='GarageCond', inplace=True)

# %%
dic37 = {'Y': 1, 'P': 2, 'N': 3}
ht['PavedDriveMap'] = ht.PavedDrive.map(dic37)
ht.drop(columns='PavedDrive', inplace=True)

# %%
dic38 = {'WD': 1, 'CWD': 2, 'VWD': 3, 'New': 4, 'COD': 5, 'Con': 6, 'ConLw': 7, 'ConLI': 8,
         'ConLD': 9, 'Oth': 10}
ht['SaleTypeMap'] = ht.SaleType.map(dic38)
ht.drop(columns='SaleType', inplace=True)

# %%
dic39 = {'Normal': 1, 'Abnorml': 2, 'AdjLand': 3, 'Alloca': 4, 'Family': 5, 'Partial': 6}
ht['SaleConditionMap'] = ht.SaleCondition.map(dic39)
ht.drop(columns='SaleCondition', inplace=True)

# %%
ht.head(10)
# Out:
#    Id  MSSubClass LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60        65.0     8450            7            5       2003
# 1   2          20        80.0     9600            6            8       1976
# 2   3          60        68.0    11250            7            5       2001
# 3   4          70        60.0     9550            7            5       1915
# 4   5          60        84.0    14260            8            5       2000
# 5   6          50        85.0    14115            5            5       1993
# 6   7          20        75.0    10084            8            5       2004
# 7   8          60         NaN    10382            7            6       1973
# 8   9          50        51.0     6120            7            5       1931
# 9  10         190        50.0     7420            5            6       1939
#
#    YearRemodAdd MasVnrArea  BsmtUnfSF  ...  KitchenQualMap  FunctionalMap  \
# ...

# %%
ht.dropna(inplace=True)

# %% [markdown]
# ### 4) Seleccion de mejores variables

# %%
corr = ht.corr() # .corr is used for find corelatio
sns.set(rc = {'figure.figsize':(30,30)})
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 15},
           xticklabels= corr, 
           yticklabels= corr,
           cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
htrain = ht[['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 
         'GarageArea', 'ExterQualMap', 'FoundationMap', 'BsmtQualMap', 'KitchenQualMap', 'SalePrice']]

# %%
htrain.head(10)
# Out:
#     OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 1             6       1976          1976         1262      1262       1262
# 2             7       2001          2002          920       920       1786
# 4             8       2000          2000         1145      1145       2198
# 6             8       2004          2005         1686      1694       1694
# 7             7       1973          1973         1107      1107       2090
# 13            7       2006          2007         1494      1494       1494
# 20            8       2005          2006         1158      1158       2376
# 21            7       1930          1950          637      1108       1108
# 22            8       2002          2002         1777      1795       1795
# 24            5       1968          2001         1060      1060       1060
#
#     FullBath  TotRmsAbvGrd  GarageCars  GarageArea  ExterQualMap  \
# 1          2             6           2         460             3
# ...

# %%
corr = htrain.corr() # .corr is used for find corelatio
sns.set(rc = {'figure.figsize':(30,30)})
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 15},
           xticklabels= corr, 
           yticklabels= corr,
           cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 5) Lectura, limpieza y mapping de tabla test

# %%
hte = pd.read_csv('C:/Users/kmyde/Desktop/HENRY DATA SCIENCE/Machine Learning/Hackathon/Housing Dreams/houses_test_raw.csv')

# %%
hte.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
dic18 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5}
hte['ExterQualMap'] = hte.ExterQual.map(dic18)
hte.drop(columns='ExterQual', inplace=True)

dic30 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5}
hte['KitchenQualMap'] = hte.KitchenQual.map(dic30)
hte.drop(columns='KitchenQual', inplace=True)

dic21 = {'Ex': 1, 'Gd': 2, 'TA': 3, 'Fa': 4, 'Po': 5, 'NA': 6}
hte['BsmtQualMap'] = hte.BsmtQual.map(dic21)
hte.drop(columns='BsmtQual', inplace=True)

dic20 = {'BrkTil': 1, 'CBlock': 2, 'PConc': 3, 'Slab': 4, 'Stone': 5, 'Wood': 6}
hte['FoundationMap'] = hte.Foundation.map(dic20)
hte.drop(columns='Foundation', inplace=True)

# %%
htest = hte[['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 
         'GarageArea', 'ExterQualMap', 'FoundationMap', 'BsmtQualMap', 'KitchenQualMap']]

# %%
htest.fillna(0,inplace=True)
# Out:
# C:\Users\kmyde\AppData\Local\Temp\ipykernel_7676\2423317965.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   htest.fillna(0,inplace=True)

# %%
htest.describe
# Out:
# <bound method NDFrame.describe of       OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0               5       1961          1961        882.0       896        896
# 1               6       1958          1958       1329.0      1329       1329
# 2               5       1997          1998        928.0       928       1629
# 3               6       1998          1998        926.0       926       1604
# 4               8       1992          1992       1280.0      1280       1280
# ...           ...        ...           ...          ...       ...        ...
# 1454            4       1970          1970        546.0       546       1092
# 1455            4       1970          1970        546.0       546       1092
# 1456            5       1960          1996       1224.0      1224       1224
# 1457            5       1992          1992        912.0       970        970
# 1458            7       1993          1994        996.0       996       2000
#
# ...

# %% [markdown]
# ### 6) Modelo de Regresion Lineal

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(htrain.drop(['SalePrice'],axis=1),htrain['SalePrice'],test_size=0.20,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression(fit_intercept = True)
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(lr.coef_)
print(lr.intercept_)
print(lr.rank_)
# Out:
# [ 1.62625251e+04  8.56384959e+00  7.02993782e+01  5.84666255e+01
#  -7.25022944e+00  8.38223161e+01 -1.14786799e+04  1.45210535e+02
#   2.03862655e+03  3.05969383e+01 -2.88549873e+03 -1.39426934e+03
#  -1.58421060e+04 -1.06947702e+04]
# -182629.54961395703
# 14

# %%
from sklearn.metrics import mean_squared_log_error
y_train_pred = lr.predict(x_train)
y_test_pred = lr.predict(x_test)
print('Error en datos de train:', mean_squared_log_error(y_train, y_train_pred, squared=False))
print('Error en datos de test:', mean_squared_log_error(y_test, y_test_pred, squared = False))
# Out:
# Error en datos de train: 0.1649098919801903
# Error en datos de test: 0.17454823504361003

# %%
from sklearn.pipeline import Pipeline
pipe = Pipeline([('LR', LinearRegression())])
pipe.fit(x_train, y_train)
Pipeline(steps=[('LR', LinearRegression())])
pipe.score(x_test, y_test)
# Out:
# 0.8240469900152252

# %%
pred = lr.predict(htest)

# %%
pred_test = pd.DataFrame(pred)
pred_test.to_csv('pred_test.csv')

# %%
pred_test.describe
# Out:
# <bound method NDFrame.describe of                   0
# 0      96076.119704
# 1     169442.810705
# 2     160449.663502
# 3     169153.473203
# 4     211716.191163
# ...             ...
# 1454   55470.940292
# 1455   66405.501720
# 1456  141256.383550
# 1457   96159.868620
# 1458  234854.598689
#
# [1459 rows x 1 columns]>
